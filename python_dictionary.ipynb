# %%
#python disctionary
#create a python dictionary with 3 key-value pairs consisting of a key string and a value string

Mailcat = {"Joe":"joe.joe@gmail.com","Anand":"anand.anand@aol.com","Lisa":"lisa@gmx.com"}
print(Mailcat)
print(type(Mailcat))
# Out:
# {'Joe': 'joe.joe@gmail.com', 'Anand': 'anand.anand@aol.com', 'Lisa': 'lisa@gmx.com'}
# <class 'dict'>

# %%
# Add a new instance "Mohammed" to the dictionary

Mailcat["Mohammed"]="mohammed@gmail.com"
print(Mailcat)
# Out:
# {'Joe': 'joe.joe@gmail.com', 'Anand': 'anand.anand@aol.com', 'Lisa': 'lisa@gmx.com', 'Mohammed': 'mohammed@gmail.com'}

# %%
# A dictionary is created with a name, the equality sign and two curly brackets name = {}
# Add an integer key, string instance to the Mailcat to show its versatility.

Mailcat[5] = "This is a string with an integer key"
print(Mailcat)
# Out:
# {'Joe': 'joe.joe@gmail.com', 'Anand': 'anand.anand@aol.com', 'Lisa': 'lisa@gmx.com', 'Mohammed': 'mohammed@gmail.com', 5: 'This is a string with an integer key'}

# %%
#show some ways to address and print the Dictionary keys and items
print(Mailcat.keys())
print(Mailcat.values())
print(Mailcat.items())
# Out:
# dict_keys(['Joe', 'Anand', 'Lisa', 'Mohammed', 5])
# dict_values(['joe.joe@gmail.com', 'anand.anand@aol.com', 'lisa@gmx.com', 'mohammed@gmail.com', 'This is a string with an integer key'])
# dict_items([('Joe', 'joe.joe@gmail.com'), ('Anand', 'anand.anand@aol.com'), ('Lisa', 'lisa@gmx.com'), ('Mohammed', 'mohammed@gmail.com'), (5, 'This is a string with an integer key')])

# %%
print(Mailcat["Lisa"])  # prints the value of the "Lisa" key-value pair
print(Mailcat[5]) # prints the value for the 5 integer key
print(Mailcat.get("Lisa")) #return the value for the key in the dictionary and if not found will return a default value
 #Note that key names must be correctly specified with UPPER case characters or lower-case characters wherever appropriate.
# Out:
# lisa@gmx.com
# This is a string with an integer key
# lisa@gmx.com

# %%
# To change the data value of a key in a dictionary, type:
Mailcat["Joe"] = "joe2.joe2@gmail.com"
print(Mailcat) # As you can see a key's value can be changed with assignment
# Out:
# {'Joe': 'joe2.joe2@gmail.com', 'Anand': 'anand.anand@aol.com', 'Lisa': 'lisa@gmx.com', 'Mohammed': 'mohammed@gmail.com', 5: 'This is a string with an integer key'}

# %%
# To delete a key-value pair you type
del Mailcat[5]
print(Mailcat)
# Out:
# {'Joe': 'joe2.joe2@gmail.com', 'Anand': 'anand.anand@aol.com', 'Lisa': 'lisa@gmx.com', 'Mohammed': 'mohammed@gmail.com'}

# %%
#some advanced dictionary functions
#.len() gives number of items (key-value pairs) in a dictionary

print(len(Mailcat))
# Out:
# 4

# %%
# The Str() function creates a string of a whole dictionary. This may be useful in some Text Mining applications

print(str(Mailcat))  # returns and prints the Mailcat dictionary as a string within curly brackets.
print(type(str(Mailcat)))
# Out:
# {'Joe': 'joe2.joe2@gmail.com', 'Anand': 'anand.anand@aol.com', 'Lisa': 'lisa@gmx.com', 'Mohammed': 'mohammed@gmail.com'}
# <class 'str'>

# %%
# This for-loop iterates through all the keys in a dictionary and prints each key on a new line.
for m in Mailcat:
    print(m)
# Out:
# Joe
# Anand
# Lisa
# Mohammed

# %%
for k in Mailcat.keys():
    print (k)
# Out:
# Joe
# Anand
# Lisa
# Mohammed

# %%
for v in Mailcat.values():
    print(v)
# Out:
# joe2.joe2@gmail.com
# anand.anand@aol.com
# lisa@gmx.com
# mohammed@gmail.com

# %%
# This loop iterates through all key-value pairs in our dictionary and prints each key-value on a new line.
for k, v in Mailcat.items():
    print(k, v)
# Out:
# Joe joe2.joe2@gmail.com
# Anand anand.anand@aol.com
# Lisa lisa@gmx.com
# Mohammed mohammed@gmail.com

# %%
# Nested Dictionaries
Mailcat["spec_mail"]= {"Rolf":"rolf.ag@gmail.com","Anne":"irine.anne@hotmail.com"}
print(str(Mailcat))  # This is a nested Dictionary with a complex multi-type structure
# Out:
# {'Joe': 'joe2.joe2@gmail.com', 'Anand': 'anand.anand@aol.com', 'Lisa': 'lisa@gmx.com', 'Mohammed': 'mohammed@gmail.com', 'spec_mail': {'Rolf': 'rolf.ag@gmail.com', 'Anne': 'irine.anne@hotmail.com'}}

# %%
# For-loop using the direct known address of a part of the multi-type structure
for k, v in Mailcat["spec_mail"].items():
    name, adress = k, v
    print(name, adress)
# Out:
# Rolf rolf.ag@gmail.com
# Anne irine.anne@hotmail.com

# %%
# Using the keys and direct known address of a exactly defined part of the multi-type structure (many possible solutions)
print(list(Mailcat["spec_mail"].keys())[0])
print(Mailcat["spec_mail"]["Rolf"])
# Out:
# Rolf
# rolf.ag@gmail.com

# %%
# "Not-so-pythonic" automation variant (complex and over bearing)
print(list(Mailcat["spec_mail"].keys())[0])
print(Mailcat["spec_mail"][list(Mailcat["spec_mail"].keys())[0]])
print(list(Mailcat["spec_mail"].keys())[1])
print(Mailcat["spec_mail"][list(Mailcat["spec_mail"].keys())[1]])
# Out:
# Rolf
# rolf.ag@gmail.com
# Anne
# irine.anne@hotmail.com

# %%
# Using "pythonic" automation. "Flattens" the Mailcat dictionary
for k, v in Mailcat["spec_mail"].items():
    Mailcat[k] = v
del Mailcat["spec_mail"]
print(Mailcat)
# Out:
# {'Joe': 'joe2.joe2@gmail.com', 'Anand': 'anand.anand@aol.com', 'Lisa': 'lisa@gmx.com', 'Mohammed': 'mohammed@gmail.com', 'Rolf': 'rolf.ag@gmail.com', 'Anne': 'irine.anne@hotmail.com'}

# %%
# How to clear or delete a Dictionary

Mailcat.clear() # deletes all elements in a dictionary.
print(Mailcat)
del Mailcat  # deletes the Dictionary
# Out:
# {}

# %%
print(Mailcat) #will return an error as Mailcat has been deleted
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 print(Mailcat)
#
# NameError: name 'Mailcat' is not defined
